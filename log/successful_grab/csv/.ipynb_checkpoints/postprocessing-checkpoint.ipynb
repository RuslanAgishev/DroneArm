# %% [markdown]
# # Log file: 15_59_10.ulg

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def init_fonts(small=12, medium=16, big=24):
    SMALL_SIZE = small
    MEDIUM_SIZE = medium
    BIGGER_SIZE = big

    plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
    plt.rc('axes', titlesize=BIGGER_SIZE)    # fontsize of the axes title
    plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
    plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('legend', fontsize=MEDIUM_SIZE)   # legend fontsize
    plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
    
init_fonts()

# %%
! ls
# Out:
# 15_59_10_actuator_controls_0_0.csv
# 15_59_10_actuator_outputs_0.csv
# 15_59_10_actuator_outputs_1.csv
# 15_59_10_battery_status_0.csv
# 15_59_10_cpuload_0.csv
# 15_59_10_ekf2_innovations_0.csv
# 15_59_10_ekf2_timestamps_0.csv
# 15_59_10_estimator_status_0.csv
# 15_59_10_input_rc_0.csv
# 15_59_10_manual_control_setpoint_0.csv
# 15_59_10_manual_control_setpoint_1.csv
# 15_59_10_rate_ctrl_status_0.csv
# 15_59_10_sensor_combined_0.csv
# 15_59_10_sensor_preflight_0.csv
# 15_59_10_system_power_0.csv
# 15_59_10_telemetry_status_0.csv
# 15_59_10_trajectory_setpoint_0.csv
# 15_59_10_vehicle_air_data_0.csv
# 15_59_10_vehicle_attitude_0.csv
# 15_59_10_vehicle_attitude_setpoint_0.csv
# 15_59_10_vehicle_land_detected_0.csv
# 15_59_10_vehicle_local_position_0.csv
# 15_59_10_vehicle_local_position_setpoint_0.csv
# 15_59_10_vehicle_magnetometer_0.csv
# 15_59_10_vehicle_rates_setpoint_0.csv
# 15_59_10_vehicle_status_0.csv
# 15_59_10_vehicle_status_flags_0.csv
# ...

# %%
pose = pd.read_csv('15_59_10_vehicle_local_position_0.csv')
z = -pose.z
z[z<=0] = z[0]
t = ( pose.timestamp - pose.timestamp[0] ) / 10e5


sp = pd.read_csv('15_59_10_vehicle_local_position_setpoint_0.csv')
t_sp = ( sp.timestamp - pose.timestamp[0] ) / 10e5

# %% [markdown]
# ## Coordinates

# %%
plt.figure(figsize=(10,8))
plt.plot(t, pose.x, color='r', linewidth=2, label='X [m]')
plt.plot(t_sp, sp.x, color='k', linewidth=2, label='X_sp [m]')
plt.legend()
plt.grid()
plt.xlabel('Time, [sec]')
plt.ylabel('Coordinates, [m]')
plt.ylim([-1.5, 1.5])
plt.title('Drone coordinates')
# Out:
# Text(0.5, 1.0, 'Drone coordinates')

# %%
plt.figure(figsize=(10,8))
plt.plot(t, pose.y, color='g', linewidth=2, label='Y [m]')
plt.plot(t_sp, sp.y, color='k', linewidth=2, label='Y_sp [m]')
plt.legend()
plt.grid()
plt.xlabel('Time, [sec]')
plt.ylabel('Coordinates, [m]')
plt.ylim([-1.5, 1.5])
plt.title('Drone coordinates')
# Out:
# Text(0.5, 1.0, 'Drone coordinates')

# %%
plt.figure(figsize=(10,8))
plt.plot(t, z, color='b', linewidth=2, label='Z [m]')
plt.plot(t_sp, -sp.z, color='k', linewidth=2, label='Z_sp [m]')
plt.legend()
plt.grid()
plt.xlabel('Time, [sec]')
plt.ylabel('Coordinates, [m]')
plt.ylim([-0.5, 1.5])
plt.title('Drone coordinates')
# Out:
# Text(0.5, 1.0, 'Drone coordinates')

# %%
pose.columns
# Out:
# Index(['timestamp', 'ref_timestamp', 'ref_lat', 'ref_lon', 'x', 'y', 'z',
#        'delta_xy[0]', 'delta_xy[1]', 'delta_z', 'vx', 'vy', 'vz', 'z_deriv',
#        'delta_vxy[0]', 'delta_vxy[1]', 'delta_vz', 'ax', 'ay', 'az', 'yaw',
#        'ref_alt', 'dist_bottom', 'dist_bottom_rate', 'eph', 'epv', 'evh',
#        'evv', 'vxy_max', 'vz_max', 'hagl_min', 'hagl_max', 'xy_valid',
#        'z_valid', 'v_xy_valid', 'v_z_valid', 'xy_reset_counter',
#        'z_reset_counter', 'vxy_reset_counter', 'vz_reset_counter', 'xy_global',
#        'z_global', 'dist_bottom_valid'],
#       dtype='object')

# %% [markdown]
# ## Angles

# %%
plt.figure(figsize=(10,8))
plt.plot(t, pose.yaw, label='Yaw [rad]')
plt.legend()
plt.grid()
plt.xlabel('Time, [sec]')
plt.ylabel('Angles [rad]')
plt.ylim([-0.2, 0.3])
# Out:
# (-0.2, 0.3)

# %%
angles = pd.read_csv('15_59_10_vehicle_attitude_0.csv')
t_ang = ( angles.timestamp - pose.timestamp[0] ) / 10e5
Q0 = angles['q[0]']
Q1 = angles['q[1]']
Q2 = angles['q[2]']
Q3 = angles['q[3]']

angles_sp = pd.read_csv('15_59_10_vehicle_attitude_setpoint_0.csv')
t_ang_sp = ( angles_sp.timestamp - pose.timestamp[0] ) / 10e5
Q0_sp = angles_sp['q_d[0]']
Q1_sp = angles_sp['q_d[1]']
Q2_sp = angles_sp['q_d[2]']
Q3_sp = angles_sp['q_d[3]']

# %%
def quaternion_to_euler(x, y, z, w):
    import math
    t0 = +2.0 * (w * x + y * z)
    t1 = +1.0 - 2.0 * (x * x + y * y)
    X = math.degrees(math.atan2(t0, t1))

    t2 = +2.0 * (w * y - z * x)
    t2 = +1.0 if t2 > +1.0 else t2
    t2 = -1.0 if t2 < -1.0 else t2
    Y = math.degrees(math.asin(t2))

    t3 = +2.0 * (w * z + x * y)
    t4 = +1.0 - 2.0 * (y * y + z * z)
    Z = math.degrees(math.atan2(t3, t4))

    return Z, Y, X

# %%
roll = []; pitch = []; yaw = []
for q0, q1, q2, q3 in zip(Q0, Q1, Q2, Q3):
    r, p, y = quaternion_to_euler(q0, q1, q2, q3)
    roll.append(r); pitch.append(p); yaw.append(y)
    
roll_sp = []; pitch_sp = []; yaw_sp = []
for q0, q1, q2, q3 in zip(Q0_sp, Q1_sp, Q2_sp, Q3_sp):
    r, p, y = quaternion_to_euler(q0, q1, q2, q3)
    roll_sp.append(r); pitch_sp.append(p); yaw_sp.append(y)

# %%
# make angular values in range (0, 180) degrees
yaw = np.array(yaw)
yaw[yaw<0] += 360
yaw -= 180

yaw_sp = np.array(yaw_sp)
yaw_sp[yaw_sp<0] += 360
yaw_sp -= 180

pitch_sp = np.array(pitch_sp)
pitch_sp[abs(pitch_sp)>20] = pitch[0]

roll_sp = np.array(roll_sp)
roll_sp[abs(roll_sp)>20] = roll[0]

# %%
plt.figure(figsize=(10,8))
plt.plot(t_ang, roll, label='Roll [grad]')
plt.plot(t_ang, pitch, label='Pitch [grad]')
plt.plot(t_ang, yaw, label='Yaw [grad]')
plt.legend()
plt.grid()
plt.xlabel('Time, [sec]')
plt.ylabel('Angles, [grad]')
plt.ylim([-20, 20])
# Out:
# (-20, 20)

# %% [markdown]
# ## Angles with setpoints

# %%
plt.figure(figsize=(10,8))
plt.plot(t_ang, roll, linewidth=3, label='Roll [grad]')
plt.plot(t_ang_sp, roll_sp, '--', color='k', linewidth=2, label='Roll_sp [grad]')
plt.legend()
plt.grid()
plt.xlabel('Time, [sec]')
plt.ylabel('Angles, [grad]')
plt.ylim([-15, 15])
# Out:
# (-15, 15)

# %%
plt.figure(figsize=(10,8))
plt.plot(t_ang, pitch, linewidth=3, label='Pitch [grad]')
plt.plot(t_ang_sp, pitch_sp, '--', color='k', linewidth=2, label='Pitch_sp [grad]')
plt.legend()
plt.grid()
plt.xlabel('Time, [sec]')
plt.ylabel('Angles, [grad]')
plt.ylim([-15, 15])
# Out:
# (-15, 15)

# %%
plt.figure(figsize=(10,8))
plt.plot(t_ang, yaw, linewidth=3, label='Yaw [grad]')
plt.plot(t_ang_sp, yaw_sp, '--', color='k', linewidth=2, label='Yaw_sp [grad]')
plt.legend()
plt.grid()
plt.xlabel('Time, [sec]')
plt.ylabel('Angles, [grad]')
plt.ylim([-15, 10])
# Out:
# (-15, 10)

# %% [markdown]
# ## Dependecies: X(pitch) and Y(roll)

# %%
plt.figure(figsize=(16,12))

plt.subplot(2,2,1)
plt.plot(t_ang, pitch, label='Pitch [grad]')
plt.legend()
plt.grid()
plt.xlabel('Time, [sec]')
plt.ylabel('Pitch, [grad]')
plt.ylim([-20, 20])

plt.subplot(2,2,2)
plt.plot(t, pose.x, label='X [m]')
plt.legend()
plt.grid()
plt.xlabel('Time, [sec]')
plt.ylabel('X, [m]')
plt.ylim([-1, 1])


plt.subplot(2,2,3)
plt.plot(t_ang, roll, label='Roll [grad]')
plt.legend()
plt.grid()
plt.xlabel('Time, [sec]')
plt.ylabel('Roll, [grad]')
plt.ylim([-20, 20])


plt.subplot(2,2,4)
plt.plot(t, pose.y, label='Y [m]')
plt.legend()
plt.grid()
plt.xlabel('Time, [sec]')
plt.ylabel('Y, [m]')
plt.ylim([-1, 1])
# Out:
# (-1, 1)

# %% [markdown]
# ## Angles deviations from setpoints during object holding period

# %%
TIME_GRAB = 146; TIME_RELEASE = 185 # define here time period of the object holding in [sec]
index_grab = len( t_ang[t_ang<TIME_GRAB] ) # start object grasping
index_release = len(t_ang) - len( t_ang[t_ang>TIME_RELEASE] ) # object release by the gripper

# %%
t_hold_object = t_ang[index_grab:index_release] # period of the object holding
# angular values at this defined time period
roll_hold_object = roll[index_grab:index_release]
pitch_hold_object = pitch[index_grab:index_release]
yaw_hold_object = yaw[index_grab:index_release]

# %%
# angles visualization at the pbject holding period
plt.plot(t_hold_object, roll_hold_object)

plt.plot(t_hold_object, pitch_hold_object)

plt.plot(t_hold_object, yaw_hold_object)

# %%
# interpolate sp values in order to have arrays of the same length with arrays of estimated robot angles
roll_sp_interp = np.interp(t_ang, t_ang_sp, roll_sp)
pitch_sp_interp = np.interp(t_ang, t_ang_sp, pitch_sp)
yaw_sp_interp = np.interp(t_ang, t_ang_sp, yaw_sp)

roll_sp_hold_object = roll_sp_interp[index_grab:index_release]
pitch_sp_hold_object = pitch_sp_interp[index_grab:index_release]
yaw_sp_hold_object = yaw_sp_interp[index_grab:index_release]

# %% [markdown]
# Mean deviation calculation: < |angle - angle_sp| >

# %%
plt.plot(t_hold_object, roll_hold_object)
plt.plot(t_hold_object, roll_sp_hold_object)

print('Roll mean deviation: %.2f[grad]' %np.mean(np.abs(roll_sp_hold_object - roll_hold_object)))
print('Roll max deviation: %.2f[grad]' %np.max(np.abs(roll_sp_hold_object - roll_hold_object)))
print('Roll standart deviation: %.2f[grad]' %np.std(roll_sp_hold_object - roll_hold_object))
# Out:
# Roll mean deviation: 0.63[grad]
# Roll max deviation: 2.61[grad]
# Roll standart deviation: 0.83[grad]

# %%
plt.plot(t_hold_object, pitch_hold_object)
plt.plot(t_hold_object, pitch_sp_hold_object)

print('Pitch mean deviation: %.2f[grad]' %np.mean(np.abs(pitch_sp_hold_object - pitch_hold_object)))
print('Pitch max deviation: %.2f[grad]' %np.max(np.abs(pitch_sp_hold_object - pitch_hold_object)))
print('Pitch standart deviation: %.2f[grad]' %np.std(pitch_sp_hold_object - pitch_hold_object))
# Out:
# Pitch mean deviation: 1.53[grad]
# Pitch max deviation: 7.15[grad]
# Pitch standart deviation: 2.03[grad]

# %%
plt.plot(t_hold_object, yaw_hold_object)
plt.plot(t_hold_object, yaw_sp_hold_object)

print('Yaw mean deviation: %.2f[grad]' %np.mean(np.abs(yaw_sp_hold_object - yaw_hold_object)))
print('Yaw max deviation: %.2f[grad]' %np.max(np.abs(yaw_sp_hold_object - yaw_hold_object)))
print('Yaw standart deviation: %.2f[grad]' %np.std(yaw_sp_hold_object - yaw_hold_object))
# Out:
# Yaw mean deviation: 2.12[grad]
# Yaw max deviation: 10.76[grad]
# Yaw standart deviation: 2.59[grad]

# %% [markdown]
# ### Manipulator test experiments

# %%
! ls ../../manipulator_test/
# Out:
# 12_18_04_vehicle_attitude_0.xlsx  12_18_04_vehicle_attitude_setpoint_0.xlsx

# %%
angles = pd.read_csv('../../manipulator_test/12_18_04/12_18_04_vehicle_attitude_0.csv')
t_ang = ( angles.timestamp - angles.timestamp[0] ) / 10e5
Q0 = angles['q[0]']
Q1 = angles['q[1]']
Q2 = angles['q[2]']
Q3 = angles['q[3]']

angles_sp = pd.read_csv('../../manipulator_test/12_18_04/12_18_04_vehicle_attitude_setpoint_0.csv')
t_ang_sp = ( angles_sp.timestamp - angles.timestamp[0] ) / 10e5
Q0_sp = angles_sp['q_d[0]']
Q1_sp = angles_sp['q_d[1]']
Q2_sp = angles_sp['q_d[2]']
Q3_sp = angles_sp['q_d[3]']

# %%
roll = []; pitch = []; yaw = []
for q0, q1, q2, q3 in zip(Q0, Q1, Q2, Q3):
    r, p, y = quaternion_to_euler(q0, q1, q2, q3)
    roll.append(r); pitch.append(p); yaw.append(y)
    
roll_sp = []; pitch_sp = []; yaw_sp = []
for q0, q1, q2, q3 in zip(Q0_sp, Q1_sp, Q2_sp, Q3_sp):
    r, p, y = quaternion_to_euler(q0, q1, q2, q3)
    roll_sp.append(r); pitch_sp.append(p); yaw_sp.append(y)

# %%
# make angular values in range (0, 180) degrees
yaw = np.array(yaw)
yaw[yaw<0] += 360
yaw -= 180

yaw_sp = np.array(yaw_sp)
yaw_sp[yaw_sp<0] += 360
yaw_sp -= 180

pitch_sp = np.array(pitch_sp)
pitch_sp[abs(pitch_sp)>20] = pitch[0]

roll_sp = np.array(roll_sp)
roll_sp[abs(roll_sp)>20] = roll[0]

# %%
plt.figure(figsize=(10,8))
plt.plot(t_ang, roll, label='Roll [grad]')
plt.plot(t_ang, pitch, label='Pitch [grad]')
plt.plot(t_ang, yaw, label='Yaw [grad]')
plt.legend()
plt.grid()
plt.xlabel('Time, [sec]')
plt.ylabel('Angles, [grad]')
# plt.ylim([-20, 20])
# Out:
# Text(0, 0.5, 'Angles, [grad]')

# %%
plt.figure(figsize=(18,4))

plt.subplot(1,3,1)
plt.plot(t_ang, roll, linewidth=3, label='Roll [grad]')
plt.plot(t_ang_sp, roll_sp, '--', color='k', linewidth=2, label='Roll_sp [grad]')
plt.legend()
plt.grid()
plt.xlabel('Time, [sec]')
plt.ylabel('Angles, [grad]')
# plt.ylim([-15, 15])

plt.subplot(1,3,2)
plt.plot(t_ang, pitch, linewidth=3, label='Pitch [grad]')
plt.plot(t_ang_sp, pitch_sp, '--', color='k', linewidth=2, label='Pitch_sp [grad]')
plt.legend()
plt.grid()
plt.xlabel('Time, [sec]')
plt.ylabel('Angles, [grad]')
# plt.ylim([-15, 15])

plt.subplot(1,3,3)
plt.plot(t_ang, yaw, linewidth=3, label='Yaw [grad]')
plt.plot(t_ang_sp, yaw_sp, '--', color='k', linewidth=2, label='Yaw_sp [grad]')
plt.legend()
plt.grid()
plt.xlabel('Time, [sec]')
plt.ylabel('Angles, [grad]')
# plt.ylim([-15, 10])
# Out:
# Text(0, 0.5, 'Angles, [grad]')

# %%
TIME_GRAB = 57.5; TIME_RELEASE = 87.5 # define here time period of the object holding in [sec]
index_grab = len( t_ang[t_ang<TIME_GRAB] ) # start object grasping
index_release = len(t_ang) - len( t_ang[t_ang>TIME_RELEASE] ) # object release by the gripper

t_hold_object = t_ang[index_grab:index_release] # period of the object holding
# angular values at this defined time period
roll_hold_object = roll[index_grab:index_release]
pitch_hold_object = pitch[index_grab:index_release]
yaw_hold_object = yaw[index_grab:index_release]

# interpolate sp values in order to have arrays of the same length with arrays of estimated robot angles
roll_sp_interp = np.interp(t_ang, t_ang_sp, roll_sp)
pitch_sp_interp = np.interp(t_ang, t_ang_sp, pitch_sp)
yaw_sp_interp = np.interp(t_ang, t_ang_sp, yaw_sp)

roll_sp_hold_object = roll_sp_interp[index_grab:index_release]
pitch_sp_hold_object = pitch_sp_interp[index_grab:index_release]
yaw_sp_hold_object = yaw_sp_interp[index_grab:index_release]

# %%
plt.figure(figsize=(18,4))

plt.subplot(1,3,1)
plt.plot(t_hold_object, roll_hold_object, label='Roll')
plt.plot(t_hold_object, roll_sp_hold_object, label='Roll_sp')
plt.legend()
plt.grid()
plt.xlabel('Time, [sec]')
plt.ylabel('Angles, [grad]')

print('Roll mean deviation: %.2f[grad]' %np.mean(np.abs(roll_sp_hold_object - roll_hold_object)))
print('Roll max deviation: %.2f[grad]' %np.max(np.abs(roll_sp_hold_object - roll_hold_object)))
print('Roll standart deviation: %.2f[grad]\n' %np.std(roll_sp_hold_object - roll_hold_object))

plt.subplot(1,3,2)
plt.plot(t_hold_object, pitch_hold_object, label='Pitch')
plt.plot(t_hold_object, pitch_sp_hold_object, label='Pitch_sp')
plt.legend()
plt.grid()
plt.xlabel('Time, [sec]')
plt.ylabel('Angles, [grad]')

print('Pitch mean deviation: %.2f[grad]' %np.mean(np.abs(pitch_sp_hold_object - pitch_hold_object)))
print('Pitch max deviation: %.2f[grad]' %np.max(np.abs(pitch_sp_hold_object - pitch_hold_object)))
print('Pitch standart deviation: %.2f[grad]\n' %np.std(pitch_sp_hold_object - pitch_hold_object))

plt.subplot(1,3,3)
plt.plot(t_hold_object, yaw_hold_object, label='Yaw')
plt.plot(t_hold_object, yaw_sp_hold_object, label='Yaw_sp')
plt.legend()
plt.grid()
plt.xlabel('Time, [sec]')
plt.ylabel('Angles, [grad]')

print('Yaw mean deviation: %.2f[grad]' %np.mean(np.abs(yaw_sp_hold_object - yaw_hold_object)))
print('Yaw max deviation: %.2f[grad]' %np.max(np.abs(yaw_sp_hold_object - yaw_hold_object)))
print('Yaw standart deviation: %.2f[grad]' %np.std(yaw_sp_hold_object - yaw_hold_object))
# Out:
# Roll mean deviation: 0.74[grad]
# Roll max deviation: 5.22[grad]
# Roll standart deviation: 0.99[grad]
#
# Pitch mean deviation: 2.68[grad]
# Pitch max deviation: 9.38[grad]
# Pitch standart deviation: 3.51[grad]
#
# Yaw mean deviation: 1.52[grad]
# Yaw max deviation: 4.61[grad]
# Yaw standart deviation: 1.93[grad]
